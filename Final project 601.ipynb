# %% [markdown]
# ## Step 1 - Set up environment

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo'

# %% [markdown]
# ## Step 2 - Read Data

# %% [markdown]
# ### 2.1 Dataset 1: Pathways

# %%
df1=pd.read_csv('Cohort_Pathways_2019.csv')
df1.head()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (6,13) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   REPORT_SCHOOL_YEAR  AGGREGATION_INDEX AGGREGATION_TYPE  AGGREGATION_CODE  \
# 0            2018-19                  0        Statewide                 0
# 1            2018-19                  0        Statewide                 0
# 2            2018-19                  0        Statewide                 0
# 3            2018-19                  0        Statewide                 0
# 4            2018-19                  0        Statewide                 0
#
#              AGGREGATION_NAME  LEA_BEDS LEA_NAME  NRC_CODE NRC_DESC  \
# 0  All Districts and Charters       NaN      NaN         0      NaN
# 1  All Districts and Charters       NaN      NaN         0      NaN
# ...

# %%
df1.dtypes
# Out:
# REPORT_SCHOOL_YEAR       object
# AGGREGATION_INDEX         int64
# AGGREGATION_TYPE         object
# AGGREGATION_CODE          int64
# AGGREGATION_NAME         object
# LEA_BEDS                float64
# LEA_NAME                 object
# NRC_CODE                  int64
# NRC_DESC                 object
# COUNTY_CODE             float64
# COUNTY_NAME              object
# NYC_IND                 float64
# BOCES_CODE              float64
# BOCES_NAME               object
# MEMBERSHIP_CODE           int64
# MEMBERSHIP_KEY            int64
# MEMBERSHIP_DESC          object
# SUBGROUP_CODE             int64
# SUBGROUP_NAME            object
# COURSE_OF_STUDY_CODE     object
# COURSE_OF_STUDY          object
# STUDENT_COUNT             int64
# dtype: object

# %%
df1.shape
# Out:
# (545676, 22)

# %%
df1.sample(5)
# Out:
#        REPORT_SCHOOL_YEAR  AGGREGATION_INDEX AGGREGATION_TYPE  \
# 88500             2018-19                  3           School
# 504885            2018-19                  3         District
# 354853            2018-19                  3           School
# 123980            2018-19                  3         District
# 180904            2018-19                  3         District
#
#         AGGREGATION_CODE                          AGGREGATION_NAME  \
# 88500       101001040002                       CHATHAM HIGH SCHOOL
# 504885      621101060000         NEW PALTZ CENTRAL SCHOOL DISTRICT
# 354853      342800011690  HS FOR LAW ENFORCEMENT AND PUBLIC SAFETY
# 123980      141800860044            GLOBAL CONCEPTS CHARTER SCHOOL
# 180904      261701060000    RUSH-HENRIETTA CENTRAL SCHOOL DISTRICT
#
#             LEA_BEDS                               LEA_NAME  NRC_CODE  \
# 88500   1.010010e+11        CHATHAM CENTRAL SCHOOL DISTRICT         5
# ...

# %% [markdown]
# ### 2.2 Dataset 2: Graduation

# %%
df2=pd.read_csv('GRAD_RATE_AND_OUTCOMES_2019.csv')
df2.head()
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   report_school_year  aggregation_index aggregation_type  aggregation_code  \
# 0            2018-19                  0        Statewide                 0
# 1            2018-19                  0        Statewide                 0
# 2            2018-19                  0        Statewide                 0
# 3            2018-19                  0        Statewide                 0
# 4            2018-19                  0        Statewide                 0
#
#              aggregation_name entity_inactive_date  lea_beds lea_name  \
# 0  All Districts and Charters                  NaN       NaN      NaN
# 1  All Districts and Charters                  NaN       NaN      NaN
# ...

# %%
df2.dtypes
# Out:
# report_school_year             object
# aggregation_index               int64
# aggregation_type               object
# aggregation_code                int64
# aggregation_name               object
# entity_inactive_date           object
# lea_beds                      float64
# lea_name                       object
# nrc_code                      float64
# nrc_desc                       object
# county_code                   float64
# county_name                    object
# nyc_ind                       float64
# boces_code                    float64
# boces_name                     object
# membership_code                 int64
# membership_key                  int64
# membership_desc                object
# subgroup_code                   int64
# subgroup_name                  object
# enroll_cnt                     object
# grad_cnt                       object
# grad_pct                       object
# local_cnt                      object
# local_pct                      object
# ...

# %%
df2.shape
# Out:
# (224138, 37)

# %%
df2.sample(5)
# Out:
#        report_school_year  aggregation_index aggregation_type  \
# 89978             2018-19                  4           School
# 12421             2018-19                  3         District
# 22165             2018-19                  3         District
# 110383            2018-19                  4           School
# 191919            2018-19                  4           School
#
#         aggregation_code                      aggregation_name  \
# 89978        70901060007         HORSEHEADS SENIOR HIGH SCHOOL
# 12421        31502060000  JOHNSON CITY CENTRAL SCHOOL DISTRICT
# 22165       132201040000     MILLBROOK CENTRAL SCHOOL DISTRICT
# 110383      251101040003                MADISON CENTRAL SCHOOL
# 191919      441800050006        PORT JERVIS SENIOR HIGH SCHOOL
#
#        entity_inactive_date      lea_beds                            lea_name  \
# 89978                   NaN  7.090106e+10  HORSEHEADS CENTRAL SCHOOL DISTRICT
# ...

# %% [markdown]
# ## Step 3 - Data cleaning and analysis

# %% [markdown]
# ### 3.1 Remove columns

# %% [markdown]
# #### 3.1.1 Dataset 1

# %%
df1=pd.read_csv('Cohort_Pathways_2019.csv', usecols=["AGGREGATION_TYPE", "AGGREGATION_NAME", "MEMBERSHIP_DESC", "SUBGROUP_NAME", "COURSE_OF_STUDY_CODE", "COURSE_OF_STUDY", "STUDENT_COUNT"])
df1.sample(5)
# Out:
#        AGGREGATION_TYPE                                AGGREGATION_NAME  \
# 19182            County                                 County: GENESEE
# 29791            County                                 County: NIAGARA
# 229497           School  REPERTORY COMPANY HIGH SCHOOL FOR THEATRE ARTS
# 117436           School                      CLEVELAND HILL HIGH SCHOOL
# 90285          District             NEW LEBANON CENTRAL SCHOOL DISTRICT
#
#                                          MEMBERSHIP_DESC  \
# 19182   2015 Total Cohort - 4 Year Outcome - August 2019
# 29791   2014 Total Cohort - 5 Year Outcome - August 2019
# 229497                2013 Total Cohort - 6 Year Outcome
# 117436  2013 Total Cohort - 6 Year Outcome - August 2019
# 90285   2015 Total Cohort - 4 Year Outcome - August 2019
#
#                      SUBGROUP_NAME COURSE_OF_STUDY_CODE  \
# 19182                  Not Migrant             STEMMATH
# 29791                        White                  CTE
# ...

# %% [markdown]
# #### 3.1.2 Dataset 2

# %%
df2=pd.read_csv('GRAD_RATE_AND_OUTCOMES_2019.csv', usecols=["aggregation_type", "aggregation_name", "membership_desc", "subgroup_name", "enroll_cnt", "grad_cnt", "grad_pct", "dropout_cnt","dropout_pct"])
df2.sample(5)
# Out:
#        aggregation_type                                   aggregation_name  \
# 53990          District                     MEXICO CENTRAL SCHOOL DISTRICT
# 47118          District          NEW YORK MILLS UNION FREE SCHOOL DISTRICT
# 100939           School                                HAMBURG HIGH SCHOOL
# 139032           School  UNIVERSITY HEIGHTS SECONDARY SCHOOL-BRONX COMM...
# 4564             County                                     County: NASSAU
#
#                                          membership_desc  \
# 53990   2015 Total Cohort - 4 Year Outcome - August 2019
# 47118   2015 Total Cohort - 4 Year Outcome - August 2019
# 100939  2014 Total Cohort - 5 Year Outcome - August 2019
# 139032  2013 Total Cohort - 6 Year Outcome - August 2019
# 4564                  2013 Total Cohort - 6 Year Outcome
#
#                          subgroup_name enroll_cnt grad_cnt grad_pct  \
# 53990   Not Economically Disadvantaged         73       70      96%
# ...
